# %% [markdown]
# <a href="https://colab.research.google.com/github/newbie-sandy/datasci_4_web_vizdatasci_4_web_viz/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CHI-SQUARE TEST IN PYTHON

# %%
import pandas as pd
import scipy
from scipy.stats import chi2_contingency as chi2

# %%
df = pd.read_csv('/content/Order_and_Referring_10_3_2023.csv')
df
# Out:
#                 NPI      LAST_NAME FIRST_NAME PARTB HHA
# 0        1558467555       .MCINDOE     THOMAS     Y   Y
# 1        1417051921        A BELLE          N     Y   Y
# 2        1972040137      A NOVOTNY  ELIZABETH     Y   Y
# 3        1760465553       A SATTAR   MUHAMMAD     Y   Y
# 4        1295400745         A'NEAL     BROGAN     Y   N
# ...             ...            ...        ...   ...  ..
# 1785834  1336502301           ZYZO       JOHN     Y   Y
# 1785835  1225502768          ZZIWA     JACKIE     N   N
# 1785836  1124277249  ZZIWA-KABENGE      IRYNE     Y   Y
# 1785837  1033160296    ZZIWAMBAZZA     NATHAN     Y   Y
# 1785838  1326140070          TOUPS    JEFFREY     Y   N
#
# [1785839 rows x 5 columns]

# %%
df['PARTB'].value_counts()
# Out:
# Y    1730812
# N      55027
# Name: PARTB, dtype: int64

# %%
df['HHA'].value_counts()
# Out:
# Y    1583742
# N     202097
# Name: HHA, dtype: int64

# %% [markdown]
# ## Create contingency table

# %%
contingency_table = pd.crosstab(df['PARTB'],df['HHA'])
contingency_table
# Out:
# HHA         N        Y
# PARTB
# N       54849      178
# Y      147248  1583564

# %%
chi2, p, _, _ = chi2(contingency_table)
print(f"chi2 value:{chi2}")
print(f"p-value:{p}")
print(f"degrees of freedom:{}")
print
# Out:
#   File "<ipython-input-15-232255a238f8>", line 3
#     print(f"p-value:"{p})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-755552315bd9> in <cell line: 1>()
# ----> 1 output1 ,output2 , output3, output4 = chi2(contingency_table)
#
# NameError: name 'chi2' is not defined
